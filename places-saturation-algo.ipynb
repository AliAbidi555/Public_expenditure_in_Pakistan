# %%
import pandas as pd
import numpy as np
import requests as re
import geopandas as gpd
import json
import warnings
import requests
import time
import folium
import sys


from shapely.prepared import prep
from shapely.geometry import Point,Polygon
from shapely.ops import transform
from scipy.spatial import Delaunay
from keplergl import KeplerGl

sys.path.insert(1, '../config/')
import kepler_configs


warnings.filterwarnings('ignore')
# %config Completer.use_jedi = False

# %%
api_key = json.load(open('../config/api_keys.json',))['key_hisham']

# %%
def func_transform_api_result(row):
    geometry = row.geometry['location']
    lat,lon = geometry['lat'],geometry['lng']
    types = row.types
    first_type = types[0]
    second_type = types[1]
    return lat,lon,first_type,second_type

def func_get_places_poi(lat,lon,resolution):
    
    url = """https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lon}
    &radius={resolution}
    &type=point_of_interest
    &key={api_key}""".format(api_key=api_key,lat=lat,lon=lon,resolution=resolution)

    payload={}
    headers = {}
    params = {}

    response = requests.request("GET", url, headers=headers, data=payload)
    places_df = []

    results = json.loads(response.content)

    places_df.append(results['results'])

    while 'next_page_token' in results:
        time.sleep(1)
        params['pagetoken'] = results['next_page_token']
        response = requests.get(url,params=params)
        results = json.loads(response.content)
        places_df.append(results['results'])
        
    final_df = pd.concat([pd.DataFrame(df) for df in places_df])
    final_df = final_df.reset_index(drop=True)
    
    return final_df


def func_flip(x, y):
    """Flips the x and y coordinate values"""
    return y, x

# %%
# lahore_vor = gpd.read_file('../data/vector/dev/LAHORE/lahore_voronoi_fishnet_1000m.shp')
# lahore_vor_stats = pd.read_csv('../data/summary-stats/lhr_pop_vor.csv')

# lahore_vor = lahore_vor.merge(lahore_vor_stats)
# lahore_vor = lahore_vor.sort_values(by='sum_pop',ascending=False).reset_index(drop=True)
# lahore_vor['centroid'] = lahore_vor.geometry.centroid

# %%
lahore_vor = gpd.read_file('../data/vector/dev/LAHORE/gmaps_places/lahore_voronoi_fishnet_1000m_updated_fix.shp')
lahore_vor['centroid'] = lahore_vor.geometry.centroid

# %%
# for ind,row in lahore_vor.iterrows():
#     if(ind<=159):
#         lahore_vor.loc[ind,'fetched']=1
#     else:
#         lahore_vor.loc[ind,'fetched']=0

# for ind,row in lahore_vor.iterrows():
#     if(ind>=160 and ind<349):
#         lahore_vor.loc[ind,'fetched']=0

# %%
len(lahore_vor[lahore_vor.fetched==0])
# Out:
# 62

# %% [markdown]
# #### get lahore overall boundary

# %%
lahore_dist_boundary = gpd.read_file('../data/vector/pak_administrative_shapefiles/District_Boundary.shp')
lahore_dist_boundary = lahore_dist_boundary[lahore_dist_boundary.DISTRICT=='LAHORE']
lahore_dist_boundary['geometry'] = lahore_dist_boundary.geometry.apply(lambda x: transform(func_flip,x))
lahore_dist_boundary = lahore_dist_boundary[lahore_dist_boundary.DISTRICT=='LAHORE'].geometry.values[0]

# %% [markdown]
# ### ALGO

# %%
#uses Delaunay to break down a polygon via triangulation, sends api request for centroid of each new polygon until
#a point of saturation is reached i.e further breaking down is not givin more than 60 api results.
#currently hardcorded to go only 4 levels deep
rdf_list = []
centroids = []
requests_counter = 0
limit = 2500
for ind, row in lahore_vor.iterrows():
    if(row.fetched!=1):
        left = len(lahore_vor)-ind
        out_str = 'requests: {req} & vor_left: {left}'.format(req=requests_counter,left=left)
        sys.stdout.write(out_str)
        sys.stdout.flush()
        resolution = 1500
        level = 1

        #LEVEL=1
        coords = row.centroid.xy
        lat,lon = coords[0][0],coords[1][0]
        centroids.append(np.array([lat,lon]))
        #print(np.array([lat,lon]))
        requests_counter+=3
        if(requests_counter<=limit):
            rdf = func_get_places_poi(lat=lat,lon=lon,resolution=resolution)
        else:
            print('LIMIT REACHED!')
            sys.exit()
            break
        rdf_list.append(rdf)

        #LEVEL=2
        if(len(rdf)==60):
            #print('reached L2')
            poly = row.geometry
            poly_points_list = []
            if(poly.geom_type=='MultiPolygon'):
                poly_points = np.array(poly[0].exterior.coords)
                poly_points_list.append(poly_points)
#                 poly_points = [np.array(pol.exterior.coords) for pol in poly]
#                 poly_points = np.concatenate(poly_points,axis=0)
#                 poly_points_list.append(poly_points)
            elif(poly.geom_type=='Polygon'):   
                poly_points = np.array(poly.exterior.coords)
                poly_points_list.append(poly_points)
            tri = Delaunay(poly_points_list[0])
            polys = poly_points[tri.simplices]
            polys = [Polygon(poly) for poly in polys]
            if(len(polys)>1):
                level += 1
                for poly in polys:
                    centroid = poly.centroid
                    #checks if new centroid in Lahore
                    if(lahore_dist_boundary.contains(centroid) == True):
                        centroid = np.array(poly.centroid.coords)
                        #print(centroid[0])
                        centroids.append(centroid[0])
                        lat,lon= centroid[0][0],centroid[0][1]
                        requests_counter+=3
                        if(requests_counter<=limit):
                            rdf = func_get_places_poi(lat=lat,lon=lon,resolution=resolution/level)
                        else:
                            print('LIMIT REACHED!')
                            sys.exit()
                            break
                        rdf_list.append(rdf)
                    else:
                        pass

                    #LEVEL=3 
                    if(len(rdf)==60):
                        #print('reached L3')
                        poly_points = np.array(poly.exterior.coords)
                        poly_points = np.concatenate((poly_points,centroid),axis=0)
                        tri = Delaunay(poly_points)
                        l2_polys = poly_points[tri.simplices]
                        l2_polys = [Polygon(poly) for poly in l2_polys]
                        if(len(l2_polys)>1):
                            for poly in l2_polys:
                                level += 1
                                centroid = poly.centroid
                                if(lahore_dist_boundary.contains(centroid)==True):
                                    centroid = np.array(centroid.coords)
                                    #print(centroid[0])
                                    centroids.append(centroid[0])
                                    lat,lon= centroid[0][0],centroid[0][1]
                                    requests_counter+=3
                                    if(requests_counter<=limit):
                                        rdf = func_get_places_poi(lat=lat,lon=lon,resolution=resolution/level)
                                    else:
                                        print('LIMIT REACHEAD!')
                                        sys.exit()
                                        break
                                    rdf_list.append(rdf)
                                else:
                                    pass

                                #LEVEL=4
                                if(len(rdf)==60):
                                    #print('reached L4')
                                    poly_points = np.array(poly.exterior.coords)
                                    poly_points = np.concatenate((poly_points,centroid),axis=0)
                                    tri = Delaunay(poly_points)
                                    l3_polys = poly_points[tri.simplices]
                                    l3_polys = [Polygon(poly) for poly in l2_polys]
                                    for poly in l3_polys:
                                        level += 1
                                        centroid = poly.centroid
                                        if(lahore_dist_boundary.contains(centroid)==True):
                                            centroid = np.array(centroid.coords)
                                            #print(centroid[0])
                                            centroids.append(centroid[0])
                                            lat,lon= centroid[0][0],centroid[0][1]
                                            requests_counter+=3
                                            if(requests_counter<=limit):
                                                rdf = func_get_places_poi(lat=lat,lon=lon,resolution=resolution/level)
                                            else:
                                                print('LIMIT REACHED!')
                                                sys.exit()
                                                break

                                            rdf_list.append(rdf)
                                        else:
                                            pass
        temp_dfs = pd.concat(rdf_list)
        fname = '../data/dev/vor_latest2.pkl'
        temp_dfs.to_pickle(fname)
        
        lahore_vor.loc[ind,'fetched']=1
        temp = lahore_vor
        temp = temp.drop(columns=['centroid'])
        temp.to_file('../data/vector/dev/LAHORE/gmaps_places/lahore_voronoi_fishnet_1000m_updated_fix2.shp')
        
    elif(row.fetched==1):
        print('fetched')
# Out:
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# requests: 0 & vor_left: 292requests: 3 & vor_left: 291requests: 6 & vor_left: 290requests: 9 & vor_left: 289requests: 12 & vor_left: 288requests: 15 & vor_left: 287requests: 18 & vor_left: 286requests: 21 & vor_left: 285requests: 24 & vor_left: 284requests: 27 & vor_left: 283requests: 30 & vor_left: 282requests: 33 & vor_left: 281requests: 36 & vor_left: 280requests: 39 & vor_left: 279requests: 42 & vor_left: 278requests: 51 & vor_left: 277requests: 54 & vor_left: 276requests: 57 & vor_left: 275requests: 60 & vor_left: 274requests: 63 & vor_left: 273requests: 66 & vor_left: 272requests: 69 & vor_left: 271requests: 72 & vor_left: 270requests: 75 & vor_left: 269requests: 78 & vor_left: 268requests: 81 & vor_left: 267requests: 84 & vor_left: 266requests: 87 & vor_left: 265requests: 90 & vor_left: 264requests: 93 & vor_left: 263requests: 96 & vor_left: 262requests: 99 & vor_left: 261requests: 102 & vor_left: 260requests: 105 & vor_left: 259requests: 108 & vor_left: 258requests: 111 & vor_left: 257requests: 114 & vor_left: 256requests: 117 & vor_left: 255requests: 120 & vor_left: 254requests: 123 & vor_left: 253requests: 126 & vor_left: 252requests: 129 & vor_left: 251requests: 132 & vor_left: 250requests: 135 & vor_left: 249requests: 138 & vor_left: 248requests: 141 & vor_left: 247requests: 144 & vor_left: 246requests: 147 & vor_left: 245requests: 150 & vor_left: 244requests: 153 & vor_left: 243requests: 156 & vor_left: 242requests: 159 & vor_left: 241requests: 162 & vor_left: 240requests: 165 & vor_left: 239requests: 168 & vor_left: 238requests: 171 & vor_left: 237requests: 174 & vor_left: 236requests: 177 & vor_left: 235requests: 180 & vor_left: 234requests: 183 & vor_left: 233requests: 186 & vor_left: 232requests: 189 & vor_left: 231fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched
# fetched

# %%
#check how many poi
rdfs = pd.concat(rdf_list)
len(rdfs.place_id.unique())
# Out:
# 1208

# %% [markdown]
# ### POST ALGO CLEANUP, SAVE, & VISUALIZATION

# %%
#poi
#rdfs = pd.read_pickle('../data/vector/dev/LAHORE/gmaps_places/10vor_test/10vor_poi.pkl')
rdfs = rdfs.drop_duplicates(subset=['place_id'])
rdfs[['lat','lon','first_type','second_type']] = rdfs.apply(func_transform_api_result,
                                                                    axis=1,
                                                                    result_type='expand')
lahore_poi = rdfs

lahore_poi_gpd = lahore_poi[['place_id','name','user_ratings_total','rating',
                                       'price_level','first_type','second_type','lat','lon']]
def func_temp(row):
    return(Point(row.lat,row.lon))
lahore_poi_gpd['geometry'] = lahore_poi_gpd.apply(func_temp,axis=1)
lahore_poi_gpd = gpd.GeoDataFrame(lahore_poi_gpd,geometry='geometry')
lahore_poi_gpd.to_file('../data/vector/dev/LAHORE/gmaps_places/lahore_ind4.shp')
#lahore_poi_gpd.to_file('../data/vector/dev/LAHORE/gmaps_places/lahore_ind3.shp')
#lahore_poi_gpd.to_file('../data/vector/dev/LAHORE/gmaps_places/lahore_ind160.shp')

#we have saved up till index 160 of lahore tesselations file - these are also flagged as fetched under the 
#lahore tesselations shape files

# %%
#vor tesselations
#lahore_vor = lahore_vor.drop(columns='centroid')
lahore_vor = gpd.GeoDataFrame(lahore_vor,geometry='geometry')
#lahore_vor.to_file('../data/vector/dev/LAHORE/gmaps_places/lahore_voronoi_fishnet_1000m_updated.shp')

# %%
#centroids 
lahore_centroirds = pd.Series(centroids)
centroids_df = pd.DataFrame(lahore_centroirds)
centroids_df = centroids_df.rename(columns={0:'lat_lon'})
centroids_df['geometry'] = centroids_df.lat_lon.apply(lambda x: Point(x[0],x[1]))
centroids_gpd = gpd.GeoDataFrame(centroids_df,geometry='geometry')
centroids_gpd = gpd.sjoin(centroids_gpd,lahore_vor,how='left')
centroids_gpd = centroids_gpd.drop(columns=['lat_lon','index_right'])
#centroids_gpd.to_csv('../data/vector/dev/LAHORE/gmaps_places/centroids_ind160.csv',index=False)

# %%
#flipping coordinates for kepler-gl
lahore_poi_gpd['geometry'] = lahore_poi_gpd.geometry.apply(lambda x: transform(func_flip,x))
centroids_gpd['geometry'] = centroids_gpd.geometry.apply(lambda x: transform(func_flip,x))
lahore_vor['geometry'] = lahore_vor.geometry.apply(lambda x: transform(func_flip,x))

# %%
map_ = KeplerGl(height=1000)
map_.add_data(data=lahore_poi_gpd,name='poi')
map_.add_data(data=centroids_gpd,name='centroids')
map_.add_data(data=lahore_vor,name='vors')
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-18651fba2e09> in <module>
#       1 map_ = KeplerGl(height=1000)
#       2 map_.add_data(data=lahore_poi_gpd,name='poi')
# ----> 3 map_.add_data(data=centroids_gpd,name='centroids')
#       4 map_.add_data(data=lahore_vor,name='vors')
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/keplergl/keplergl.py in add_data(self, data, name)
#     134         copy.update({name: normalized})
#     135
# --> 136         self.data = copy
#     137
#     138     def save_to_html(self, data=None, config=None, file_name='keplergl_map.html', read_only=False, center_map=False):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     572             # we explicitly compare silent to True just in case the equality
#     573             # comparison above returns something other than True/False
# --> 574             obj._notify_trait(self.name, old_value, new_value)
#     575
#     576     def __set__(self, obj, value):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/traitlets/traitlets.py in _notify_trait(self, name, old_value, new_value)
#    1137             new=new_value,
#    1138             owner=self,
# -> 1139             type='change',
#    1140         ))
#    1141
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     603             if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     604                 # Send new state to front-end
# --> 605                 self.send_state(key=name)
#     606         super(Widget, self).notify_change(change)
#     607
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in send_state(self, key)
#     487             state, buffer_paths, buffers = _remove_buffers(state)
#     488             msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 489             self._send(msg, buffers=buffers)
#     490
#     491
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipywidgets/widgets/widget.py in _send(self, msg, buffers)
#     735         """Sends a message to the model in the front-end."""
#     736         if self.comm is not None and self.comm.kernel is not None:
# --> 737             self.comm.send(data=msg, buffers=buffers)
#     738
#     739     def _repr_keys(self):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/comm/comm.py in send(self, data, metadata, buffers)
#     121         """Send a message to the frontend-side version of this comm"""
#     122         self._publish_msg('comm_msg',
# --> 123             data=data, metadata=metadata, buffers=buffers,
#     124         )
#     125
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/comm/comm.py in _publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      63         data = {} if data is None else data
#      64         metadata = {} if metadata is None else metadata
# ---> 65         content = json_clean(dict(data=data, comm_id=self.comm_id, **keys))
#      66         self.kernel.session.send(self.kernel.iopub_socket, msg_type,
#      67             content,
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     143         out = {}
#     144         for k,v in obj.items():
# --> 145             out[str(k)] = json_clean(v)
#     146         return out
#     147     if isinstance(obj, datetime):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     143         out = {}
#     144         for k,v in obj.items():
# --> 145             out[str(k)] = json_clean(v)
#     146         return out
#     147     if isinstance(obj, datetime):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     143         out = {}
#     144         for k,v in obj.items():
# --> 145             out[str(k)] = json_clean(v)
#     146         return out
#     147     if isinstance(obj, datetime):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     143         out = {}
#     144         for k,v in obj.items():
# --> 145             out[str(k)] = json_clean(v)
#     146         return out
#     147     if isinstance(obj, datetime):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     143         out = {}
#     144         for k,v in obj.items():
# --> 145             out[str(k)] = json_clean(v)
#     146         return out
#     147     if isinstance(obj, datetime):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     129
#     130     if isinstance(obj, list):
# --> 131         return [json_clean(x) for x in obj]
#     132
#     133     if isinstance(obj, dict):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in <listcomp>(.0)
#     129
#     130     if isinstance(obj, list):
# --> 131         return [json_clean(x) for x in obj]
#     132
#     133     if isinstance(obj, dict):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     129
#     130     if isinstance(obj, list):
# --> 131         return [json_clean(x) for x in obj]
#     132
#     133     if isinstance(obj, dict):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in <listcomp>(.0)
#     129
#     130     if isinstance(obj, list):
# --> 131         return [json_clean(x) for x in obj]
#     132
#     133     if isinstance(obj, dict):
#
# ~/anaconda3/envs/jugnu/lib/python3.6/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     149
#     150     # we don't understand it, it's probably an unserializable object
# --> 151     raise ValueError("Can't clean for JSON: %r" % obj)
#
# ValueError: Can't clean for JSON: <shapely.geometry.point.Point object at 0x7f57b09695c0>

# %%
map_.save_to_html(file_name='../viz/cells_poi2_places.html',config=kepler_configs.lahore_vor_poi_test)
# Out:
# Map saved to ../viz/cells_poi2_places.html!

# %% [markdown]
# ### combine lahore_poi

# %%
lahore_poi = gpd.read_file('../data/vector/dev/LAHORE/gmaps_places/lahore_ind2.shp')
lahore_poi_2 = gpd.read_file('../data/vector/dev/LAHORE/gmaps_places/lahore_ind160.shp')
lahore_poi_3 = gpd.read_file('../data/vector/dev/LAHORE/gmaps_places/lahore_ind3.shp')
lahore_poi_4 = gpd.read_file('../data/vector/dev/LAHORE/gmaps_places/lahore_ind4.shp')

#lahore_poi_gpd.to_file('../data/vector/dev/LAHORE/gmaps_places/lahore_ind2.shp')

# %%
lahore_combined_gpd = pd.concat([lahore_poi,lahore_poi_2,lahore_poi_3,lahore_poi_4]).reset_index(drop=True)

# %%
lahore_combined_gpd.drop_duplicates(subset='place_id')
# Out:
#                           place_id                            name  \
# 0      ChIJ2QeB5YMEGTkRYiR-zGy-OsI                          Lahore
# 1      ChIJXUl_8rwSGTkRqaEZK6UVUzI                           Wagah
# 2      ChIJm769CLETGTkRmm3x2sHt3iQ                Darbar Shahjamal
# 3      ChIJLfgtYeITGTkRTf1lrx9kn_g                    Azadi Museum
# 4      ChIJcYS4dpcSGTkR6t9fdM9FI_U  National Logistics Cell Office
# ...                            ...                             ...
# 60287  ChIJx-mH3xqtGTkRWB8QHOVuJ1M      Karma wala karyana store ?
# 60348  ChIJm210j59XGDkRqDCH15miDpI                           Manga
# 60423  ChIJbRjlzgipGTkRfJHvpFF23-I              Apartments E block
# 60456  ChIJATndfnmrGTkR5i1MgREmOso                 ButterScotchINC
# 60541  ChIJSfg8WrOpGTkRZTpmDheuN4M     Jamia Mahboob Masjid Ghosia
#
#        user_ratin  rating price_leve           first_type         second_typ  \
# 0             NaN     NaN        NaN             locality          political
# 1          7111.0     4.5        NaN   tourist_attraction  point_of_interest
# 2             3.0     3.3        NaN               mosque   place_of_worship
# 3             5.0     2.6        NaN               museum  point_of_interest
# 4             8.0     3.8        NaN    point_of_interest      establishment
# ...           ...     ...        ...                  ...                ...
# 60287         NaN     NaN       None                 food  point_of_interest
# 60348         NaN     NaN       None  sublocality_level_2        sublocality
# 60423         NaN     NaN       None    point_of_interest      establishment
# 60456         NaN     NaN       None       clothing_store  point_of_interest
# 60541         NaN     NaN       None               mosque   place_of_worship
#
#              lat        lon                   geometry
# 0      31.520370  74.358747  POINT (31.52037 74.35875)
# 1      31.604757  74.574136  POINT (31.60476 74.57414)
# 2      31.603353  74.563741  POINT (31.60335 74.56374)
# 3      31.603989  74.564205  POINT (31.60399 74.56421)
# 4      31.602750  74.566538  POINT (31.60275 74.56654)
# ...          ...        ...                        ...
# 60287  31.269862  74.247963  POINT (31.26986 74.24796)
# 60348  31.306175  74.050575  POINT (31.30617 74.05058)
# 60423  31.311563  74.367184  POINT (31.31156 74.36718)
# 60456  31.362168  74.275921  POINT (31.36217 74.27592)
# 60541  31.297696  74.345768  POINT (31.29770 74.34577)
#
# [53059 rows x 10 columns]

# %%
sjoined = gpd.sjoin(lahore_vor,lahore_combined_gpd,how='left',op='contains')

# %%
sjoined = sjoined.reset_index(drop=True)

# %%
sjoined = sjoined.drop_duplicates(subset=['place_id'])

# %%
sjoined = sjoined.drop(columns='centroid')

# %%
sjoined.to_file('../data/vector/dev/LAHORE/gmaps_places/lahore_all_poi_mapped.shp')

# %%
sjoined.columns
# Out:
# Index(['vor_id', 'area_sq', 'area_sqrt', 'sum_pop', 'mean_pop', 'max_pop',
#        'min_pop', 'fetched', 'geometry', 'index_right', 'place_id', 'name',
#        'user_ratin', 'rating', 'price_leve', 'first_type', 'second_typ', 'lat',
#        'lon'],
#       dtype='object')

# %%
sjoined[['vor_id', 'place_id', 'name',
       'user_ratin', 'rating', 'price_leve', 'first_type', 'second_typ', 'lat',
       'lon']].to_csv('../data/summary-stats/lahore_poi_vor.csv',index=False)
